# %%
import pandas as pd

# %%
df = pd.read_csv('Geom(1).csv')

print(df.head())
# Out:
#          .1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0   82    0    81.55081    8.571335    80.20810    17.04875    77.98663
# 1   82    0    81.55078    8.571320    80.20813    17.04877    77.98663
# 2  129    0   128.29330   13.484180   126.18100    26.82060   122.68630
# 3  108    0   107.40840   11.289080   105.64000    22.45447   102.71410
# 4  145    0   144.20570   15.156620   141.83140    30.14719   137.90320
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 112  Unnamed: 113  \
# 0    25.33940    74.91074    33.35240  ...      74.91058     -33.35272
# 1    25.33939    74.91071    33.35242  ...      74.91058     -33.35272
# 2    39.86319   117.84740    52.46902  ...     117.84720     -52.46951
# 3    33.37384    98.66290    43.92755  ...      98.66272     -43.92796
# 4    44.80746   132.46410    58.97681  ...     132.46390     -58.97736
#
#    Unnamed: 114  Unnamed: 115  Unnamed: 116  Unnamed: 117  Unnamed: 118  \
# ...

# %%
# v=[]

# for i in range(122):
#   if i %2 == 0:

#     b=lambda i:'X'+str(int((i+1)/2)+1)
#     v.append(b(i))
#   else:
#     b1=lambda i:'Y'+str(int((i+1)/2))
#     v.append(b1(i))

# print(v)

# %%
df.max()
# Out:
#                 145.000000
#  .1               0.000000
# Unnamed: 2      144.205700
# Unnamed: 3       15.156620
# Unnamed: 4      141.831400
#                    ...
# Unnamed: 117    -10.395810
# Unnamed: 118    144.205600
# Unnamed: 119     -5.226624
# Unnamed: 120    145.000000
# Unnamed: 121     -0.000244
# Length: 122, dtype: float64

# %%
df.shape
# Out:
# (22, 122)

# %%
d2=df[df.columns[::2]]

# %%
d1=df[df.columns[1::2]]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 90))
for i in range(22):
 
    ax=plt.subplot(8,3,i+1)
    plt.plot(d1.iloc[i],d2.iloc[i],"s")
  
    plt.subplots_adjust(wspace=0.35)
    plt.xlabel("circle number "+str(i+1),fontsize=15)
    plt.subplots_adjust(bottom=0.1)
    ax.set_xlim(-150, 150)
    ax.set_ylim(-150, 150)
    
   
    
   
plt.show()

# %%
df[:10]
# Out:
#          .1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0   82    0    81.55081    8.571335    80.20810    17.04875    77.98663
# 1   82    0    81.55078    8.571320    80.20813    17.04877    77.98663
# 2  129    0   128.29330   13.484180   126.18100    26.82060   122.68630
# 3  108    0   107.40840   11.289080   105.64000    22.45447   102.71410
# 4  145    0   144.20570   15.156620   141.83140    30.14719   137.90320
# 5   89    0    88.51245    9.303040    87.05511    18.50415    84.64404
# 6   83    0    82.54532    8.675842    81.18625    17.25665    78.93768
# 7  133    0   132.27140   13.902280   130.09360    27.65225   126.49050
# 8  116    0   115.36450   12.125310   113.46510    24.11777   110.32260
# 9   79    0    78.56723    8.257751    77.27365    16.42503    75.13345
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 112  Unnamed: 113  \
# 0    25.33940    74.91074    33.35240  ...      74.91058     -33.35272
# ...

# %%
import keras
from keras import layers

# This is the size of our encoded representations
encoding_dim = 30  # 32

# This is our input image
input_img = keras.Input(shape=(122,))
# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation=keras.layers.LeakyReLU(alpha=1))(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(122, activation=keras.layers.LeakyReLU(alpha=1))(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

autoencoder.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# Using TensorFlow backend.

# %%
import keras
from keras import layers

# This is the size of our encoded representations
encoding_dim = 60  # 32

# This is our input image
input_img = keras.Input(shape=(122,))
# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation=keras.layers.LeakyReLU(alpha=1))(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(122, activation=keras.layers.LeakyReLU(alpha=1))(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# %%
# from sklearn.datasets import make_regression
# from sklearn.preprocessing import StandardScaler
# from keras.models import Sequential
# from keras.layers import Dense

# %%
import numpy as np
x_train= df[:17]
x_test = df[17:]
print (x_train.shape)
print (x_test.shape)

# %%
# df = StandardScaler().fit_transform(df)

# %%
import numpy as np

# %%
# x_train = np.array(x_train)

# %%
# x_test= np.array(x_test)

# %%
autoencoder.fit(x_train, x_train,
                epochs=200,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test))

# Encode and decode some digits

# %%
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# decoded_imgs

# %%
import matplotlib.pyplot as plt

# %%
#separate X from y
for i in range(5):
    n=decoded_imgs[:, ::2]
    k=decoded_imgs[:, 1::2]
# print(n)

# %%
for i in range(5):
    n1=encoded_imgs[:, ::2]
    k1=encoded_imgs[:, 1::2]
     
    
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 30))
for i in range(5):
 
    ax=plt.subplot(3,3,i+1)
    plt.plot(d1.iloc[i+17],d2.iloc[i+17],"s",color='green')
  #16 first number of test data
    plt.subplots_adjust(wspace=0.35)
    plt.xlabel("circle number "+str(i+1),color = 'blue',fontsize=20)
    plt.suptitle('Original test Circles', fontsize=20)
    plt.subplots_adjust(bottom=0.1)
    ax.set_xlim(-150, 150)
    ax.set_ylim(-150, 150)
   
   
   
plt.show()

# %%
plt.figure(figsize=(30, 30))
for i in range(5):
 
    ax=plt.subplot(3,3,i+1)
    plt.plot(n[i],k[i], "o",color='purple')
    plt.subplots_adjust(wspace=0.35)
    plt.xlabel("circle number "+str(i+1),color='blue',fontsize=20)
    plt.suptitle('Prediction Model', fontsize=20)
    plt.subplots_adjust(bottom=0.1)
    ax.set_xlim(-150, 150)
    ax.set_ylim(-150, 150)
    
plt.show()

# %%
plt.figure(figsize=(30, 30))
for i in range(5):
 
    ax=plt.subplot(3,3,i+1)
    plt.plot(n1[i],k1[i], "o",color='red')
    plt.subplots_adjust(wspace=0.35)
    plt.xlabel("circle number "+str(i+1),color='blue',fontsize=20)
    plt.suptitle('Prediction Model', fontsize=20)
    plt.subplots_adjust(bottom=0.1)
    ax.set_xlim(-150, 150)
    ax.set_ylim(-150, 150)
    
plt.show()

# %%
import keras
from keras import layers

# This is the size of our encoded representations
encoding_dim = 30 # 30

# This is our input image
input_img = keras.Input(shape=(122,))
# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation=keras.layers.LeakyReLU(alpha=1))(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(122, activation=keras.layers.LeakyReLU(alpha=1))(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# %%
import numpy as np
x_train= df[:17]
x_test = df[17:]
print (x_train.shape)
print (x_test.shape)

# %%
autoencoder.fit(x_train, x_train,
                epochs=200,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test))

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
for i in range(5):
    n1=encoded_imgs[:, ::2]
    k1=encoded_imgs[:, 1::2]
     
    
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 20))
for i in range(5):
 
    ax=plt.subplot(2,3,i+1)
    plt.plot(d1.iloc[i+17],d2.iloc[i+17],"s",color='green')
  #17 first number of test data
    plt.subplots_adjust(wspace=0.35)
    plt.xlabel("circle number "+str(i+1),color = 'blue',fontsize=20)
    plt.suptitle('Original test Circles', fontsize=20)
    plt.subplots_adjust(bottom=0.1)
    ax.set_xlim(-150, 150)
    ax.set_ylim(-150, 150)
   
   
   
plt.show()

# %%
plt.figure(figsize=(30, 20))
for i in range(5):
 
    ax=plt.subplot(2,3,i+1)
    plt.plot(n[i],k[i], "o",color='purple')
    plt.subplots_adjust(wspace=0.35)
    plt.xlabel("circle number "+str(i+1),color='blue',fontsize=20)
    plt.suptitle('Prediction Model', fontsize=20)
    plt.subplots_adjust(bottom=0.1)
    ax.set_xlim(-150, 150)
    ax.set_ylim(-150, 150)
    
plt.show()

# %%
plt.figure(figsize=(30, 20))
for i in range(5):
 
    ax=plt.subplot(2,3,i+1)
    plt.plot(n1[i],k1[i], "o",color='red')
    plt.subplots_adjust(wspace=0.35)
    plt.xlabel("circle number "+str(i+1),color='blue',fontsize=20)
    plt.suptitle('Prediction Model', fontsize=20)
    plt.subplots_adjust(bottom=0.1)
    ax.set_xlim(-150, 150)
    ax.set_ylim(-150, 150)
    
plt.show()
